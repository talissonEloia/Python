# %%
print('olá mundo')
# Out:
# olá mundo

# %%
mundo = input('O que é mundo:')
if mundo == 'mundo':
  print('Enquanto %s for %s'%(mundo,mundo))
  print('A gaby é do negão!')
# Out:
# O que é mundo:carro

# %% [markdown]
# Lista de exercício *1*

# %% [markdown]
# 1. Faça um programa que calcula o Índice de Massa Corporal (IMC) de
# uma pessoa a partir de sua altura em metros e o seu peso em Kg,
# como dado na fórmula: imc = peso/altura²

# %%
peso = float(input("Digite o peso: "))
altura = float(input("Sua altura:"))


imc = peso/altura**2
print("seu imc é",imc)
# Out:
# Digite o peso: 86
# Sua altura:1.78
# seu imc é 27.143037495265748

# %% [markdown]
# 2. Faça um Programa que peça 2 números inteiros e um número
# real. Calcule e mostre:
#
# * o produto do dobro do primeiro com metade do segundo
# * a soma do triplo do primeiro com o terceiro.
# * o terceiro elevado ao cubo.

# %%
n1 = int(input("Digite n1; "))
n2 = int(input("Digite n2; "))
n3 = float(input("Digite n3; "))

a = n1 * (n2/2)
b = (n1*3) + n3
c = n3**3
print("a: ", a)
print("b: ", b)
print("c: ", c)
      )
# Out:
# Digite n1; 3
# Digite n2; 3
# Digite n3; 2
# a:  4.5
# b:  11.0
# c:  8.0

# %% [markdown]
# 3. Escreva um programa que leia o número de um funcionário, seu
# número de horas trabalhadas, o valor que recebe por hora e calcula o
# salário desse funcionário. A seguir, mostre o número e o salário do
# funcionário, com duas casas decimais.
#
# ***Entrada**
# * O arquivo de entrada contém 2 números inteiros e 1 número com duas casas
# decimais, representando o número, quantidade de horas trabalhadas e o valor
# que o funcionário recebe por hora trabalhada, respectivamente.
#  **Saída**
# * Imprima o número e o salário do funcionário, conforme exemplo fornecido,
# com um espaço em branco antes e depois da igualdade. No caso do salário,
# também deve haver um espaço em branco após o R$.

# %%
num_f = int(input("Numero do funcionário: "))
h_trab = int(input("Horas trabalhadas: "))
val_ht = float(input("Valor H/T: "))

salario = h_trab*val_ht
print("Numero: ", num_f, "salário: ", salario)
# Out:
# Numero do funcionário: 4535
# Horas trabalhadas: 60
# Valor H/T: 20
# Numero:  4535 salário:  1200.0

# %% [markdown]
# 4. Escreva um programa que leia três valores com ponto flutuante
# de dupla precisão: A, B e C. Em seguida, calcule e mostre:
# * a) a área do triângulo retângulo que tem A por base e C por
# altura.
# * b) a área do círculo de raio C. (pi = 3.14159)
# * c) a área do trapézio que tem A e B por bases e C por altura.
# * d) a área do quadrado que tem lado B.
# * e) a área do retângulo que tem lados A e B.

# %%
a = int(input("Valor A "))
b = int(input("Valor B "))
c = int(input("Valor C "))
pi = float(3.14159)

id_a = (a*c)/2
print("A", id_a)

id_b = 3*pi*c
print("B ", round(id_b,2))

id_c = ((a+b)*c)/2
print("C ", id_c)

id_d = b*b
print("D ", round(id_d,2))
# Out:
# Valor A 2
# Valor B 3
# Valor C 4
# A 4.0
# B  37.7
# C  10.0
# D  9

# %% [markdown]
# 5. João Papo-de-Pescador, homem de bem, comprou um microcomputador para
# controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso
# de peixes maior que o estabelecido pelo regulamento de pesca do estado de
# São Paulo (50 quilos) deve pagar uma multa de R$ 4,00 por quilo excedente.
# João precisa que você faça um programa que leia a variável peso (peso de
# peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos
# além do limite e na variável multa o valor da multa que João deverá pagar.
# Imprima os dados do programa com as mensagens adequadas.

# %%
peso = int(input("Peso "))
ex_peso = peso - 50

multa = ex_peso*4.00

print("O valor da multa é: ", round(multa,2))
# Out:
# Peso 55
# O valor da multa é:  20.0

# %% [markdown]
# 6. Faça um Programa para uma loja de tintas. O programa deverá pedir o
# tamanho em metros quadrados da área a ser pintada. Considere que a
# cobertura da tinta é de 1 litro para cada 6 metros quadrados e que a tinta é
# vendida em latas de 18 litros, que custam R$ 80,00 ou em galões de 3,6
# litros, que custam R$ 25,00. Informe ao usuário as quantidades de tinta a
# serem compradas e os respectivos preços em 3 situações:
#
# * comprar apenas latas de 18 litros;
# * comprar apenas galões de 3,6 litros;
# * misturar latas e galões, de forma que o desperdício de tinta seja menor. Acrescente 10% de folga e sempre arredonde os valores para cima, isto é, considere latas cheias.

# %%
area = float(input("Área "))
ar_litro = area/6
print("Tinta necessária:",ar_litro)

caso1 = round(ar_litro/18.00,2)
valor1 = round(caso1*80.0, 2)
print("Em galões de 18L:",round(caso1)
print("Custo R$", valor1)

caso2 = round(ar_litro/3.6, 2)
valor2 = round(caso1*25.0,2)
print("Em galões de 3.6L:",caso2)
print("Custo R$",round(valor2,2))
# Out:
#   File "<ipython-input-33-65f37d54a758>", line 8
#     print("Custo R$", valor1)
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# 7. Faça um programa que peça o tamanho de um arquivo para
# download (em MB) e a velocidade de um link de Internet (em
# Mbps), calcule e informe o tempo aproximado de download do
# arquivo usando este link (em minutos)

# %%
arq = float(input("Tamanho do arquivo:"))
mbps = float(input("Velocidade de conexão:"))

download = round((arq//mbps)/60,0)
print("O tempo aproximado de download do arquivo é:", round(download,2),"minutos" )
# Out:
# Tamanho do arquivo:1000
# Velocidade de conexão:2
# O tempo aproximado de download do arquivo é: 8.0 m e  0 s

# %% [markdown]
# 8. Faça um programa que leia o nome de um vendedor, o seu salário fixo e o
# total de vendas efetuadas por ele no mês (em dinheiro). Sabendo que este
# vendedor ganha 15% de comissão sobre suas vendas efetuadas, informar o
# total a receber no final do mês, com duas casas decimais.
#
#  **Entrada**
#
# * O arquivo de entrada contém um texto (primeiro nome do vendedor) e 2 valores de com duas casas decimais, representando o salário fixo do vendedor e montante total das vendas efetuadas por este vendedor, respectivamente.
#
#  **Saída**
#
# * Imprima o total que o funcionário deverá receber, conforme exemplo fornecido.

# %%
nome = input("NOME: ")
salario = float(input("salário: "))
vendas = float(input("Vendas: "))

com = vendas*0.15

print("comissão R$",com,"\nSalário do mês R$", round(salario+com,2)
)
# Out:
# NOME: Jonas
# salário: 1200
# Vendas: 2000
# comissão R$ 300.0
# Salário do mês R$ 1500.0

# %%
frase = "Instagram, Whatsapp, YouTube, Twitter, Tik Tok ,Instagram, Whatsapp, YouTube, Twitter, Tik Tok,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube,Instagram, Whatsapp, YouTub,Facebook, Instagram, Whatsapp, YouTube,Instagram, Whatsapp, YouTube,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube,Instagram, Whatsapp, YouTube, Twitter\n,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube, Twitter, TikTok,Instagram, Whatsapp, YouTube, Twitter, Tiktok ,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp,Instagram, Whatsapp, YouTube, Twitter, Snapchat,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube, Twitter,Facebook, Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube, Twitter,Facebook, Instagram, Whatsapp, YouTube Instagram, Whatsapp, YouTube,Instagram, Whatsapp, YouTube,Instagram, Whatsapp, YouTube, Twitter,Whatsapp, YouTube, Pinterest,Instagram, Whatsapp\nFacebook, Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube\n,Instagram, Whatsapp, YouTub,Instagram, Whatsapp, YouTube,Instagram, Whatsapp, Snapchat, Tiktok,Facebook, Instagram, YouTube, Twitter, Snapchat\n,Instagram, Whatsapp, YouTube,Facebook, Instagram, Whatsapp, YouTube, Twitter, Tik tok,Instagram, YouTube,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, YouTube, Twitter,Instagram, Whatsapp, Twitter,Whatsapp,Whatsapp, YouTube"


print('REDE SOCIAL MAIS USADADA')

print("Whatsapp:",frase.count("Whatsapp")) # 2
print("Instagram:",frase.count("Instagram")) # 2
print("YouTube:",frase.count("YouTube")) # 2
print("Twitter:",frase.count("Twitter")) # 2
print("Tik Tok:",frase.count("Tik Tok")) # 2
# Out:
# REDE SOCIAL MAIS USADADA
# Whatsapp: 39
# Instagram: 38
# YouTube: 34
# Twitter: 22
# Tik Tok: 2

# %%
frase = "Qual o principal canal que você acessa ou usa a internet hoje? Tenho acesso a internet em casa e pelo celular. Acesso somente no celular pela rede WiFi Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Acesso somente no celular pela rede WiFiTenho acesso a internet em casa e pelo celular., Acesso somente no celular pela rede WiFiTenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular., Acesso somente no celular pela rede WiFiTenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular., Uso apenas em casa., Acesso somente no celular pela rede WiFi, Acesso somente no celular pelos meus dados.Tenho acesso a internet em casa e pelo celular., Acesso apenas no trabalho.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular., Acesso somente no celular pela rede WiFi Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular., Acesso somente no celular pela rede WiFi, Acesso somente no celular pelos meus dados.Uso apenas em casa.Tenho acesso a internet em casa e pelo celular., Uso apenas em casa.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular., Acesso somente no celular pela rede WiFi Tenho acesso a internet em casa e pelo celular Uso apenas em casa.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Uso apenas em casa.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular.Tenho acesso a internet em casa e pelo celular. Tenho acesso a internet em casa e pelo celular"

print('Acessoa internet')
print("Tenho acesso a internet em casa e pelo celular.:",frase.count("Tenho acesso a internet em casa e pelo celular")) # 2
print("Acesso somente no celular pela rede WiFi:",frase.count("Acesso somente no celular pela rede WiFi")) # 2
print("Uso apenas em casa:",frase.count("Uso apenas em casa")) # 2
print("Acesso somente no celular pelos meus dados:",frase.count("Acesso somente no celular pelos meus dados")) # 2
# Out:
# Acessoa internet
# Tenho acesso a internet em casa e pelo celular.: 36
# Acesso somente no celular pela rede WiFi: 8
# Uso apenas em casa: 5
# Acesso somente no celular pelos meus dados: 2

# %%
frase = "Inteligência emocional Inteligência emocional, CriatividadeLiderança, Visão crítica/social, Inteligência emocional, Comunicação, Empreendedorismo, Consciência cultural, Interpretação de informações, Resolução de problemas, Uso das tecnologias digitais Inteligência emocional Visão crítica/social, Inteligência emocional, Criatividade, Comunicação Liderança, Visão crítica/social, Inteligência emocional, Criatividade, Trabalho em equipe, Empreendedorismo, Interpretação de informações, Resolução de problemas Liderança, Inteligência emocional, Criatividade, Trabalho em equipe Liderança, Inteligência emocional, Criatividade, Comunicação, Interpretação de informações, Resolução de problemas, Uso das tecnologias digitais Visão crítica/social, Criatividade Visão crítica/social, Inteligência emocional, Criatividade, Comunicação, Consciência cultural, Interpretação de informações, Adaptação Inteligência emocional, Comunicação, Resolução de problemas, Adaptação Liderança, Visão crítica/social, Inteligência emocional, Criatividade, Comunicação, Trabalho em equipe, Empreendedorismo, Consciência cultural, Interpretação de informações, Resolução de problemas, Adaptação, Uso das tecnologias digitais Liderança, Visão crítica/social, Inteligência emocional, Comunicação, EmpreendedorismoLiderança, Visão crítica/social, Comunicação, Empreendedorismo Liderança, Criatividade, Interpretação de informações, Uso das tecnologias digitais Criatividade, Trabalho em equipe, Empreendedorismo, Uso das tecnologias digitais Liderança, Visão crítica/social, Inteligência emocional, Criatividade, Comunicação, Trabalho em equipe, Empreendedorismo, Consciência cultural, Interpretação de informações, Resolução de problemas, Adaptação Inteligência emocional, Criatividade Liderança, Visão crítica/social, Inteligência emocional, Comunicação, Trabalho em equipe, Consciência cultural, Interpretação de informações, Resolução de problemas, Uso das tecnologias digitais Inteligência emocional, Trabalho em equipe, Empreendedorismo, Uso das tecnologias digitais Liderança, Inteligência emocional Visão crítica/social, Criatividade, Trabalho em equipe, Empreendedorismo Liderança, Empreendedorismo, Uso das tecnologias digitais Liderança, Inteligência emocional, Empreendedorismo, Interpretação de informações, Resolução de problemas Comunicação, Trabalho em equipe, Empreendedorismo, Interpretação de informações, Adaptação Liderança, Visão crítica/social, Inteligência emocional, Empreendedorismo, Interpretação de informações, Resolução de problemas Criatividade, Comunicação Liderança, Inteligência emocional, Criatividade, Comunicação, Trabalho em equipe, Consciência cultural, Resolução de problemas, Uso das tecnologias digitais Liderança, Comunicação, Empreendedorismo, Consciência cultural, Interpretação de informações, Resolução de problemas, Adaptação, Uso das tecnologias digitais Liderança, Inteligência emocional, Comunicação, Trabalho em equipe, Empreendedorismo, Interpretação de informações, Uso das tecnologias digitais Liderança, Visão crítica/social, Comunicação, Trabalho em equipe, Empreendedorismo, Interpretação de informações Liderança, Visão crítica/social, Inteligência emocional, Criatividade, Comunicação, Trabalho em equipe, Empreendedorismo, Resolução de problemas, Adaptação, Uso das tecnologias digitais Inteligência emocional, Empreendedorismo Criatividade, Adaptação, Uso das tecnologias digitais Liderança, Inteligência emocional, Consciência cultural, Adaptação Visão crítica/social, Inteligência emocional, Comunicação, Trabalho em equipe, Consciência cultural, Interpretação de informações, Resolução de problemas, Adaptação, Uso das tecnologias digitais Liderança, Comunicação, Interpretação de informações Liderança, Visão crítica/social, Criatividade, Trabalho em equipe, Empreendedorismo, Interpretação de informações, Resolução de problemas, Adaptação, Uso das tecnologias digitais Liderança, Inteligência emocional, Comunicação Liderança, Visão crítica/social, Inteligência emocional, Empreendedorismo, Interpretação de informações, Resolução de problemas, Adaptação, Uso das tecnologias digitais Liderança, Visão crítica/social, Inteligência emocional, Empreendedorismo"


print('Que habilidades você sente que precisa desenvolver melhor e você ver como necessárias nos dias atuais?')


print("Inteligência emocional:",frase.count("Inteligência emocional")) # 2
print("Criatividade:",frase.count("Criatividade")) # 2
print("Liderança",frase.count("Liderança")) # 2
print("Comunicação",frase.count("Comunicação")) # 2
print("Empreendedorismo:",frase.count("Empreendedorismo")) # 2
print("Liderança",frase.count("Liderança")) # 2
print("Consciência cultural",frase.count("Consciência cultural")) # 2
print("Interpretação de informações",frase.count(", Interpretação de informações")) # 2
print(" Resolução de problemas",frase.count(" Resolução de problemas")) # 2
print("Empreendedorismo:",frase.count("Empreendedorismo")) # 2
print("Liderança",frase.count("Liderança")) # 2
print("Uso das tecnologias digitais",frase.count("Uso das tecnologias digitais")) # 2
# Out:
# Que habilidades você sente que precisa desenvolver melhor e você ver como necessárias nos dias atuais?
# Inteligência emocional: 28
# Criatividade: 18
# Liderança 25
# Comunicação 20
# Empreendedorismo: 21
# Liderança 25
# Consciência cultural 9
# , Interpretação de informações 18
#  Resolução de problemas 15
# Empreendedorismo: 21
# Liderança 25
# Uso das tecnologias digitais 16
